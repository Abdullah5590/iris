# %%
import pandas as pd
import numpy as np

# %%
missing = pd.read_csv(r'C:\Users\5590a\Desktop\my project\car.csv')
missing
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %%
missing['EngineV'].notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4340     True
# 4341     True
# 4342     True
# 4343    False
# 4344     True
# Name: EngineV, Length: 4345, dtype: bool

# %%
missing[missing['Price'].isnull()]
# Out:
#               Brand  Price       Body  Mileage  EngineV Engine Type  \
# 17    Mercedes-Benz    NaN        van      240      2.2      Diesel
# 29    Mercedes-Benz    NaN  crossover        0      4.6      Petrol
# 50    Mercedes-Benz    NaN      sedan      145      3.2      Diesel
# 55    Mercedes-Benz    NaN  crossover        0      3.0      Diesel
# 91    Mercedes-Benz    NaN  crossover        0      3.0      Diesel
# ...             ...    ...        ...      ...      ...         ...
# 4229         Toyota    NaN      hatch       76      1.0      Petrol
# 4231  Mercedes-Benz    NaN  crossover       27      3.0      Diesel
# 4260            BMW    NaN  crossover        0      3.0      Diesel
# 4273     Volkswagen    NaN      other      197      2.0      Diesel
# 4305            BMW    NaN  crossover        1      3.0      Diesel
#
#      Registration  Year             Model
# 17            yes  2007              Vito
# 29            yes  2016           GLS 500
# ...

# %%
missing['Price'].fillna(missing['Price'].max())
# Out:
# 0         4200.0
# 1         7900.0
# 2        13300.0
# 3        23000.0
# 4        18300.0
#           ...
# 4340    125000.0
# 4341      6500.0
# 4342      8000.0
# 4343     14200.0
# 4344     13500.0
# Name: Price, Length: 4345, dtype: float64

# %%
missing[missing['Price'].isnull()]
# Out:
#               Brand  Price       Body  Mileage  EngineV Engine Type  \
# 17    Mercedes-Benz    NaN        van      240      2.2      Diesel
# 29    Mercedes-Benz    NaN  crossover        0      4.6      Petrol
# 50    Mercedes-Benz    NaN      sedan      145      3.2      Diesel
# 55    Mercedes-Benz    NaN  crossover        0      3.0      Diesel
# 91    Mercedes-Benz    NaN  crossover        0      3.0      Diesel
# ...             ...    ...        ...      ...      ...         ...
# 4229         Toyota    NaN      hatch       76      1.0      Petrol
# 4231  Mercedes-Benz    NaN  crossover       27      3.0      Diesel
# 4260            BMW    NaN  crossover        0      3.0      Diesel
# 4273     Volkswagen    NaN      other      197      2.0      Diesel
# 4305            BMW    NaN  crossover        1      3.0      Diesel
#
#      Registration  Year             Model
# 17            yes  2007              Vito
# 29            yes  2016           GLS 500
# ...

# %%
missing['Price'] = missing['Price'].fillna(missing['Price'].std())
missing
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %%
missing[missing["Price"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Body, Mileage, EngineV, Engine Type, Registration, Year, Model]
# Index: []

# %%
missing[missing['EngineV'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Body, Mileage, EngineV, Engine Type, Registration, Year, Model]
# Index: []

# %%
missing[''] = missing[''].fillna(missing[''].std())

# %%
missing[missing['Model'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Brand, Price, Body, Mileage, EngineV, Engine Type, Registration, Year, Model]
# Index: []
